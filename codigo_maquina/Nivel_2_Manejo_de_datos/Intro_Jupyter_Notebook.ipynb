# %% [markdown]
# # Encabezado nivel 1

# %% [markdown]
# ## Encabezado nivel 2

# %% [markdown]
# ### Encabezado nivel 3

# %% [markdown]
# #### Encabezado nivel 4

# %% [markdown]
# ##### Encabezado nivel 5

# %% [markdown]
# Texto base

# %%
import pandas as pd

# %%
datos = pd.Series([100, 200, 300], index=["Juan", "Pedro", "Luis"])
datos.plot(ylabel="Ahorros", kind="pie")
# Out:
# <Axes: ylabel='Ahorros'>
