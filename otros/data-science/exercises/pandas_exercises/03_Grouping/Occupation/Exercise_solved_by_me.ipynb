# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user", sep="|")
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
users.groupby(by=["occupation"])["age"] \
      .mean() \
      .astype(int)
# Out:
# occupation
# administrator    38
# artist           31
# doctor           43
# educator         42
# engineer         36
# entertainment    29
# executive        38
# healthcare       41
# homemaker        32
# lawyer           36
# librarian        40
# marketing        37
# none             26
# other            34
# programmer       33
# retired          63
# salesman         35
# scientist        35
# student          22
# technician       33
# writer           36
# Name: age, dtype: int64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
sub = users.groupby(by="occupation") \
           .agg(
               hombres=("gender", lambda x: (x == "M").sum()),
               total=("user_id", "count")
           )
sub
# Out:
#                hombres  total
# occupation
# administrator       43     79
# artist              15     28
# doctor               7      7
# educator            69     95
# engineer            65     67
# entertainment       16     18
# executive           29     32
# healthcare           5     16
# homemaker            1      7
# lawyer              10     12
# librarian           22     51
# marketing           16     26
# none                 5      9
# other               69    105
# programmer          60     66
# retired             13     14
# salesman             9     12
# scientist           28     31
# student            136    196
# technician          26     27
# writer              26     45

# %%
sub["ratio_hombres"] = round(sub["hombres"] / sub["total"], 4) * 100
sub
# Out:
#                hombres  total  ratio_hombres
# occupation
# administrator       43     79          54.43
# artist              15     28          53.57
# doctor               7      7         100.00
# educator            69     95          72.63
# engineer            65     67          97.01
# entertainment       16     18          88.89
# executive           29     32          90.62
# healthcare           5     16          31.25
# homemaker            1      7          14.29
# lawyer              10     12          83.33
# librarian           22     51          43.14
# marketing           16     26          61.54
# none                 5      9          55.56
# other               69    105          65.71
# programmer          60     66          90.91
# retired             13     14          92.86
# salesman             9     12          75.00
# scientist           28     31          90.32
# student            136    196          69.39
# technician          26     27          96.30
# writer              26     45          57.78

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
ages = users.groupby(by="occupation") \
     .agg(
         min_age=("age", "min"),
         max_age=("age", "max")
     ).reset_index()
ages
# Out:
#        occupation  min_age  max_age
# 0   administrator       21       70
# 1          artist       19       48
# 2          doctor       28       64
# 3        educator       23       63
# 4        engineer       22       70
# 5   entertainment       15       50
# 6       executive       22       69
# 7      healthcare       22       62
# 8       homemaker       20       50
# 9          lawyer       21       53
# 10      librarian       23       69
# 11      marketing       24       55
# 12           none       11       55
# 13          other       13       64
# 14     programmer       20       63
# 15        retired       51       73
# 16       salesman       18       66
# 17      scientist       23       55
# 18        student        7       42
# 19     technician       21       55
# 20         writer       18       60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
users.groupby(by=["occupation", "gender"])["age"].mean().astype(int)
# Out:
# occupation     gender
# administrator  F         40
#                M         37
# artist         F         30
#                M         32
# doctor         M         43
# educator       F         39
#                M         43
# engineer       F         29
#                M         36
# entertainment  F         31
#                M         29
# executive      F         44
#                M         38
# healthcare     F         39
#                M         45
# homemaker      F         34
#                M         23
# lawyer         F         39
#                M         36
# librarian      F         40
#                M         40
# marketing      F         37
#                M         37
# none           F         36
#                M         18
# other          F         35
#                M         34
# programmer     F         32
#                M         33
# retired        F         70
#                M         62
# salesman       F         27
#                M         38
# scientist      F         28
#                M         36
# student        F         20
#                M         22
# technician     F         38
#                M         32
# writer         F         37
#                M         35
# Name: age, dtype: int64

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
gender_groups = users.groupby(by="occupation") \
     .agg(
         total=("gender", "count"),
         women=("gender", lambda x: (x == "F").sum()),
         men=("gender", lambda x: (x == "M").sum())
     )
gender_groups["women_percentage"] = round(gender_groups["women"] / gender_groups["total"], 4) * 100
gender_groups["men_percentage"] = round(gender_groups["men"] / gender_groups["total"], 4) * 100
gender_groups
# Out:
#                total  women  men  women_percentage  men_percentage
# occupation
# administrator     79     36   43             45.57           54.43
# artist            28     13   15             46.43           53.57
# doctor             7      0    7              0.00          100.00
# educator          95     26   69             27.37           72.63
# engineer          67      2   65              2.99           97.01
# entertainment     18      2   16             11.11           88.89
# executive         32      3   29              9.38           90.62
# healthcare        16     11    5             68.75           31.25
# homemaker          7      6    1             85.71           14.29
# lawyer            12      2   10             16.67           83.33
# librarian         51     29   22             56.86           43.14
# marketing         26     10   16             38.46           61.54
# none               9      4    5             44.44           55.56
# other            105     36   69             34.29           65.71
# programmer        66      6   60              9.09           90.91
# retired           14      1   13              7.14           92.86
# salesman          12      3    9             25.00           75.00
# scientist         31      3   28              9.68           90.32
# student          196     60  136             30.61           69.39
# technician        27      1   26              3.70           96.30
# writer            45     19   26             42.22           57.78
