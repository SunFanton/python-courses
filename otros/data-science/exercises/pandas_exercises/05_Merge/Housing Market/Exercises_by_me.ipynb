# %% [markdown]
# # Housing Market

# %% [markdown]
# ### Introduction:
#
# This time we will create our own dataset with fictional numbers to describe a house market. As we are going to create random data don't try to reason of the numbers.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Create 3 differents Series, each of length 100, as follows:
# 1. The first a random number from 1 to 4
# 2. The second a random number from 1 to 3
# 3. The third a random number from 10,000 to 30,000

# %%
rand1 = np.random.randint(1, high=5, size=100, dtype="i2")
rand2 = np.random.randint(1, high=4, size=100, dtype="i2")
rand3 = np.random.randint(10000, high=30001, size=100, dtype="i8")

ser1 = pd.Series(data=rand1, name="rand1")
ser2 = pd.Series(data=rand2, name="rand2")
ser3 = pd.Series(data=rand3, name="rand3")

print(ser1, ser2, ser3)
# Out:
# 0     3
# 1     2
# 2     2
# 3     4
# 4     3
#      ..
# 95    3
# 96    3
# 97    3
# 98    1
# 99    3
# Name: rand1, Length: 100, dtype: int16 0     2
# 1     1
# 2     2
# 3     2
# 4     1
#      ..
# 95    3
# 96    1
# 97    1
# 98    1
# 99    3
# Name: rand2, Length: 100, dtype: int16 0     15434
# 1     20023
# 2     12192
# 3     11910
# 4     27148
#       ...
# 95    10182
# 96    15789
# 97    20270
# 98    17208
# 99    26311
# Name: rand3, Length: 100, dtype: int64

# %% [markdown]
# ### Step 3. Let's create a DataFrame by joinning the Series by column

# %%
'''df = pd.DataFrame(data={
    "Series1": ser1,
    "Series2": ser2,
    "Series3": ser3
})'''

df = pd.concat([ser1, ser2, ser3], axis=1)
df.head()
# Out:
#    rand1  rand2  rand3
# 0      3      2  15434
# 1      2      1  20023
# 2      2      2  12192
# 3      4      2  11910
# 4      3      1  27148

# %% [markdown]
# ### Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
df.rename(columns={"rand1": "bedrs", "rand2": "bathrs", "rand3": "price_sqr_meter"}, inplace=True)
df.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      3       2            15434
# 1      2       1            20023
# 2      2       2            12192
# 3      4       2            11910
# 4      3       1            27148

# %% [markdown]
# ### Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
bigcolumn = pd.concat([ser1, ser2, ser3], axis=0).to_frame()
bigcolumn
# Out:
#         0
# 0       3
# 1       2
# 2       2
# 3       4
# 4       3
# ..    ...
# 95  10182
# 96  15789
# 97  20270
# 98  17208
# 99  26311
#
# [300 rows x 1 columns]

# %% [markdown]
# ### Step 6. Oops, it seems it is going only until index 99. Is it true?

# %%
len(bigcolumn)
# Out:
# 300

# %% [markdown]
# ### Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
bigcolumn.reset_index(drop=True, inplace=True)
bigcolumn.tail()
# Out:
#          0
# 295  10182
# 296  15789
# 297  20270
# 298  17208
# 299  26311
