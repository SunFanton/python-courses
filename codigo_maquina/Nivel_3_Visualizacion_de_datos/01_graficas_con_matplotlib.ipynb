# %% [markdown]
# # Gráficas con Matplotlib

# %% [markdown]
# ![Gráfico matplotlib](matplotlib1.png "Partes de un gráfico en matplotlib")

# %% [markdown]
# ## Creación de gráficas de líneas (plot)

# %%
import matplotlib.pyplot as plt

# %%
eje_x = ["a", "b", "c", "d", "e"] # eje x
datos1 = [10, 20, 30, 40, 50] # eje y
datos2 = [20, 30, 40, 50, 60] 

plt.plot(eje_x, datos1) # plot pinta el lienzo, pero no lo muestra. Por defecto grafica lineas
plt.plot(eje_x, datos2)
plt.show() # muestra el lienzo y lo limpia para proximas graficas

# %%
plt.plot(eje_x, datos1) 
plt.show()

plt.plot(eje_x, datos2) 
plt.show()

# %% [markdown]
# ## Generar datos a graficar

# %% [markdown]
# ### Examen de certificación para estudiantes de 5 niveles

# %%
import numpy as np

# %%
# eje x
años = ["2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]

# valores del eje y
nivel1 = np.random.rand(10)*100
nivel2 = np.random.rand(10)*200 + 100
nivel3 = np.random.rand(10)*300 + 200
nivel4 = np.random.rand(10)*400 + 300
nivel5 = np.random.rand(10)*500 + 400

# %% [markdown]
# ## Personalización de gráficas

# %%
# Introducir graficas de datos con color, marcador, etiqueta y estilo
plt.plot(años, nivel1, label="Nivel 1", color="purple", marker="<", linestyle="-")
plt.plot(años, nivel2, label="Nivel 2", color="red", marker="*", linestyle="--")
plt.plot(años, nivel3, label="Nivel 3", color="blue", marker="^", linestyle=":")
plt.plot(años, nivel4, label="Nivel 4", color="black", marker=".", linestyle="-.")
plt.plot(años, nivel5, label="Nivel 5", color="green", marker="+", linestyle=" ")

# Activar leyendas
plt.legend(loc="upper right")

# Titulo de las graficas
plt.title("Examen de certificación")

# Etiquetas de los ejes
plt.xlabel("Años que se ha realizado el examen")
plt.ylabel("Puntaje")

# Personalizar eje de puntajes de 0 a 1000 en incrementos de 50
plt.yticks(np.arange(0, 1001, 50))

# Activar cuadricula
plt.grid()

# Activar marcas menores
plt.minorticks_on()

plt.show()

# %% [markdown]
# ## Gráfica de barras verticales (bar)

# %%
eje_x = np.arange(0, 10)

"""
En este caso, se puso que se graficara primero el nivel5, luego el 4 y asi, porque al tener los valores mas altos
si se grafican a lo ultimo se superponen con los valores mas bajos y los tapan.
Esto tambien se puede solvertar y personalizar con la ubicacion y ancho de las barras
"""

plt.bar(eje_x, nivel5)
plt.bar(eje_x, nivel4)
plt.bar(eje_x, nivel3)
plt.bar(eje_x, nivel2)
plt.bar(eje_x, nivel1)

plt.show()

# Personalizando las barras:
plt.bar(eje_x, nivel5, width=1/5) # la anchura por defecto de cada barra es 1 punto
plt.bar(eje_x + 0.2, nivel4, width=1/5)
plt.bar(eje_x + 0.4, nivel3, width=1/5)
plt.bar(eje_x + 0.6, nivel2, width=1/5)
plt.bar(eje_x + 0.8, nivel1, width=1/5)

plt.show()

# %% [markdown]
# ## Gráfica de barras horizontales (hbar)

# %%
plt.barh(eje_x, nivel5, height=1/5)
plt.barh(eje_x + 0.2, nivel4, height=1/5)
plt.barh(eje_x + 0.4, nivel3, height=1/5)
plt.barh(eje_x + 0.6, nivel2, height=1/5)
plt.barh(eje_x + 0.8, nivel1, height=1/5)

plt.show()

# %% [markdown]
# ## Gráfica de barras verticales apiladas

# %%
plt.bar(eje_x, nivel5)
plt.bar(eje_x, nivel4, bottom=nivel5)
plt.bar(eje_x, nivel3, bottom=nivel4+nivel5)
plt.bar(eje_x, nivel2, bottom=nivel3+nivel4+nivel5)
plt.bar(eje_x, nivel1, bottom=nivel2+nivel3+nivel4+nivel5)

plt.show()

# %% [markdown]
# ## Gráfico de dispersión (scatter)

# %%
plt.scatter(eje_x, nivel1, marker="*")
plt.scatter(eje_x, nivel2)
plt.scatter(eje_x, nivel3)
plt.scatter(eje_x, nivel4)
plt.scatter(eje_x, nivel5)

plt.show()

# %% [markdown]
# ## Gráfica de torta (pie)

# %%
plt.pie(nivel1, 
        labels=["México", "Colombia", "España", "Estados Unidos", 
                "Ecuador", "Argentina", "Venezuela", "Puerto Rico", "Honduras", "Uruguay"])

plt.show()

# %% [markdown]
# ## Combinar las gráficas

# %%
plt.bar(eje_x, nivel1, width=1/5)
plt.bar(eje_x + 0.2, nivel2, width=1/5)

plt.plot(años, nivel3)

plt.scatter(eje_x, nivel4)
plt.scatter(eje_x, nivel5)

plt.show()
